# %%
import json

# %%
tree_structure = {

    0 : {'node_id'   : 0,
         'title'     : 'Olive Oil',
         'image'     :  'olive_oil.jpeg',
         'children'  : [1,2,3],
         'parent_id' : None,
         'is_recipe' : False,
         },
    
    ##########################################

    1: {'node_id': 1,
        'title': 'Garlic',
        'image': 'garlic.jpeg',
        'children': [4, 5],
        'parent_id': 0,
        'is_recipe': False,

        },

    2 : {'node_id': 2,
        'title': 'Black Pepper',
        'image': 'black_pepper.jpeg',
        'children': [6],
        'parent_id': 0,
         'is_recipe': False,

         },

    3 : {'node_id': 3,
        'title': 'Butter',
        'image': 'butter.jpeg',
        'children': [7],
        'parent_id': 0,
        'is_recipe': False,
         },
    
    ##########################################
    
    4 : {'node_id': 4,
        'title': 'Parsley',
        'image': 'parsley.jpeg',
        'children': [8, 10, 11],
        'parent_id': 1,
        'is_recipe': False,
         },
    5 : {'node_id': 5,
        'title': 'Tomato',
        'image': 'tomato.jpeg',
        'children': [12],
        'parent_id': 1,
        'is_recipe': False,
         },
    6 : {'node_id': 6,
        'title': 'Cheese',
        'image': 'cheese.jpeg',
        'children': [13, 14],
        'parent_id': 2,
        'is_recipe': False,
         },
    7 : {'node_id': 7,
        'title': 'Garlic',
        'image': 'garlic.jpeg',
        'children': [15],
        'parent_id': 3,
        'is_recipe': False,
         },
    
    
    ##########################################
    
    8 : {'node_id': 8,
        'title': "Aglio e' Olio",
        'image': 'aglio_e_olio.jpeg',
        'children': None,
        'parent_id': 4,
        'is_recipe': True,
         },
    
    10 : {'node_id': 10,
        'title': 'Truffle',
        'image': 'truffle.jpeg',
        'children': [17],
        'parent_id': 4,
        'is_recipe': False,
         },
    11 : {'node_id': 11,
        'title': 'White Wine',
        'image': 'white_wine.jpeg',
        'children': [18],
        'parent_id': 4,
        'is_recipe': False,
         },
    
    12 : {'node_id': 12,
        'title': 'Basil',
        'image': 'basil.jpeg',
        'children': [19],
        'parent_id': 5,
        'is_recipe': False,
         },
    13 : {'node_id': 13,
        'title': 'Caccio e Peppe',
        'image': 'caccio_e_peppe.jpeg',
        'children': None,
        'parent_id': 6,
        'is_recipe': True,
         },
    14 : {'node_id': 14,
        'title': 'Guanchale',
        'image': 'guanchale.jpeg',
        'children': [20, 21],
        'parent_id': 6,
        'is_recipe': False,
         },
    15 : {'node_id': 15,
        'title': 'Cheese',
        'image': 'cheese.jpeg',
        'children': [22, 23],
        'parent_id': 7,
        'is_recipe': False,
         },
    
    ##########################################

    
    17 : {'node_id': 17,
        'title': 'Tartufata',
        'image': 'tartufata.jpeg',
        'children': None,
        'parent_id': 10,
        'is_recipe': True,
         },
    18 : {'node_id': 18,
        'title': 'Clams',
        'image': 'clams.jpeg',
        'children': [24],
        'parent_id': 11,
        'is_recipe': False,
         },
    19 : {'node_id': 19,
        'title': 'Marinara',
        'image': 'marinara.jpeg',
        'children': None,
        'parent_id': 12,
        'is_recipe': True,
         },
    
    20 : {'node_id': 20,
        'title': 'Tomato',
        'image': 'tomato.jpeg',
        'children': [25],
        'parent_id': 14,
        'is_recipe': False,
         },
    21 : {'node_id': 21,
        'title': 'Eggs',
        'image': 'egg.jpeg',
        'children': [26],
        'parent_id': 14,
        'is_recipe': False,
         },
    22 : {'node_id': 22,
        'title': 'Cream',
        'image': 'cream.jpeg',
        'children': [27],
        'parent_id': 15,
        'is_recipe': False,
         },
    23 : {'node_id': 23,
        'title': 'Buro',
        'image': 'buro.jpeg',
        'children': None,
        'parent_id': 15,
        'is_recipe': True,
         },
    
    ##########################################
    
    24 : {'node_id': 24,
        'title': 'Vongole',
        'image': 'vongole.jpeg',
        'children': None,
        'parent_id': 18,
        'is_recipe': True,
         },
    25 : {'node_id': 25,
        'title': 'Alamatriciana',
        'image': 'alamatriciana.jpeg',
        'children': None,
        'parent_id': 20,
        'is_recipe': True,
         },
    26 : {'node_id': 26,
        'title': 'Carbonara',
        'image': 'carbonara.jpeg',
        'children': None,
        'parent_id': 21,
        'is_recipe': True,
         },
    27 : {'node_id': 27,
        'title': 'Alfredo',
        'image': 'alfredo.jpeg',
        'children': None,
        'parent_id': 22,
        'is_recipe': True,
         },

}

# %%
with open("tree_structure.json", "w") as fp:
    json.dump(tree_structure, fp)

# %%
igredients = {
    
    8 : {'recipe' : 8,
        'igredients' : [0, 1, 4],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
        },
    
    17 : {'recipe' : 17,
        'igredients' : [0, 1, 4, 10],
                 'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         
         },
    
    24 : {'recipe' : 24 ,
        'igredients' : [0, 1, 4, 11, 18],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         },
    
    19 : {'recipe' : 19 ,
        'igredients' : [0, 1, 5, 12],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         },
    
    25 : {'recipe' : 25,
        'igredients' : [0, 2, 6, 14, 20],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         },
    
    26 : {'recipe' : 26,
        'igredients' : [0, 2, 6, 14, 21],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         },
    
    27 : {'recipe' : 27,
        'igredients' : [0, 3, 7, 15, 22],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         },
    
    23 : {'recipe' : 23,
        'igredients' : [0, 3, 7, 15],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         },
    
    13 : {'recipe' : 13,
        'igredients' : [0, 2, 6],
        'text': ['Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing eli',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollas vel sint commodi',
                 'Lorem sectlestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitel sint commodi',
                 'Lorem ipsum dolor sit amet coiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing euas vel sint commodi',
                 'Lorem ipsum dolor sit alitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet conselit. Maxime mollitia, molestiae quas vel sint commodi',
                 'Lorem ipsum dolor sit amet consectetur adipisicing elit. Maxime mollitia, molestiae quas vel sdi',
                 'Loremestiae quas vel sint commodi'
                ]
         }
}

# %%
with open("recipe_ingredients.json", "w") as fp:
    json.dump(igredients, fp)

# %%
    
    '''
    9 : {'node_id': 9,
        'title': 'Anchovie',
        'image': 'anchovie.jpeg',
        'children': [16],
        'parent_id': 4,
        'is_recipe': False,
         },
    '''

# %%
    
    '''
    16 : {'node_id': 16,
        'title': 'E Alici',
        'image': 'e_alici.jpeg',
        'children': None,
        'parent_id': 9,
        'is_recipe': True,
         },
    '''

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c5e51d848bce> in <module>
# ----> 1 recipe_ingredients
#
# NameError: name 'recipe_ingredients' is not defined
